# %%
import numpy as np
from scipy.stats import randint

np.random.seed(seed=917213144)


def sgameRand(low,high, term):
    listOut = []
    rv = randint(1,100).rvs()
    listOut = [rv]
    while rv <= term: 
        rv = randint(1,100).rvs()
        listOut = listOut+[rv]
    return listOut

# %%
res={i: [ sgameRand(1,100,80) for i in range(20) ] for i in range(1,4) }
[sum([len(val) for val in res[key]]) for key in res.keys() ]
# Out:
# [113, 70, 89]

# %%
len([j for i in res[1][:13] for j in i])
# Out:
# 68

# %%
resX={1:res2[3],2:res[2],3:res[3]}

# %%
res
# Out:
# {1: [[88],
#   [73, 31, 91],
#   [41, 69, 70, 47, 47, 59, 89],
#   [9, 19, 87],
#   [64, 86],
#   [27, 99],
#   [92],
#   [39, 16, 44, 4, 51, 72, 64, 45, 97],
#   [31, 44, 58, 9, 34, 56, 34, 54, 47, 91],
#   [92],
#   [20, 1, 22, 85],
#   [50, 13, 21, 80, 21, 84],
#   [61, 3, 99],
#   [13, 77, 69, 11, 87],
#   [67, 58, 7, 8, 8, 8, 11, 50, 25, 47, 94],
#   [65, 41, 56, 36, 13, 75, 93],
#   [85],
#   [54, 25, 59, 30, 73, 95],
#   [14, 18, 20, 77, 63, 93],
#   [60, 84]],
#  2: [[30, 14, 87],
#   [66, 77, 60, 43, 42, 83],
#   [87],
#   [4, 65, 54, 96],
#   [80, 95],
#   [49, 57, 28, 96],
#   [31, 85],
#   [7, 45, 28, 83],
#   [13, 80, 66, 28, 96],
#   [83],
#   [95],
#   [73, 30, 29, 70, 40, 97],
#   [34, 32, 23, 20, 15, 51, 97],
#   [72, 85],
#   [6, 69, 71, 29, 84],
#   [8, 30, 88],
#   [69, 9, 17, 95],
#   [29, 69, 93],
#   [37, 99],
#   [9, 45, 72, 58, 96]],
#  3: [[85],
#   [12, 35, 71, 40, 14, 9, 98],
#   [26, 21, 29, 82],
#   [2, 23, 82],
#   [3, 44, 6, 72, 85],
#   [7, 46, 40, 37, 80, 94],
#   [87],
#   [44, 32, 88],
#   [31, 36, 95],
#   [45, 53, 62, 99],
#   [6, 65, 68, 52, 29, 27, 10, 12, 86],
#   [85],
#   [57, 39, 39, 41, 47, 49, 44, 34, 89],
#   [32, 43, 47, 44, 87],
#   [45, 88],
#   [72, 90],
#   [37, 89],
#   [12, 5, 69, 26, 86],
#   [40, 19, 43, 13, 41, 64, 90],
#   [19, 71, 3, 3, 33, 30, 18, 59, 1, 97]]}

# %%
len(res[1][:15])
# Out:
# 15

# %%
import json

# %%
with open('match_dict.json', 'w') as f:
    json.dump(expMatch, f)

# %%
expMatch.keys()
# Out:
# dict_keys([2, 16, 18, 20, 22, 24])

# %%
def randomMatch(n, rounds):
    subjs = [i for i in range(1,2*n+1)]
    random.shuffle(subjs)
    initialMatch = [[subjs[i], subjs[-(i+1)]] for i in range(n)]
    
    return initialMatch
