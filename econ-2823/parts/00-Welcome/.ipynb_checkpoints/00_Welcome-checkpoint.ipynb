# %% [markdown]
# # Welcome
#
# This is a **Jupyter Notebook**. It contains two types of cells:
#
# - **Markdown cells** — formatted text (like this one)
# - **Code cells** — executable Python code
#
# To run a cell, select it and press `Ctrl+Enter` (Windows) or `Command+Return` (Mac). You can also click the **Run** button in the toolbar.
#
# We'll use notebooks throughout this course to write, run, and document our analysis — all in one place.
#
# For more details, see the [Jupyter documentation](https://jupyter-notebook.readthedocs.io/).

# %% [markdown]
# # Markdown
#
# Markdown cells let you write formatted text alongside your code. To create one, change the cell type to "Markdown" in the toolbar. Double-click a rendered cell to edit it; run it to render again.
#
# Here are the basics:
#
# You can make text *italic*, **bold**, or ***both***.
#
# Create block quotes with `>`:
#
# > Facts are stubborn things, but statistics are pliable.
# >
# > — *Mark Twain*
#
# Bulleted lists:
# - Apples
# - Oranges
# - Grapes
#
# Numbered lists:
# 1. Wake up
# 2. Get out of bed
# 3. Drag a comb across my head
#
# For more on Markdown syntax, see the [Markdown guide](https://www.markdownguide.org/basic-syntax/).

# %% [markdown]
# ### Try it yourself
#
# Double-click the cell below and write some Markdown. Try a heading, a list, and a block quote. Then run the cell to see it rendered.

# %% [markdown]
# *Double-click to edit this cell. Replace this text with your own Markdown.*

# %% [markdown]
# # LaTeX
#
# Markdown cells also support LaTeX for writing math. This will be essential for expressing economic models and statistical formulas.

# %% [markdown]
# **Inline math** uses single dollar signs: `$x^2$` renders as $x^2$.

# %% [markdown]
# **Display math** uses double dollar signs for centered equations:
#
# $$\bar{x} = \frac{1}{n} \sum_{i=1}^{n} x_i$$

# %% [markdown]
# Some examples you'll see in this course:
#
# - A regression equation: $y_i = \beta_0 + \beta_1 x_i + \varepsilon_i$
# - A probability: $P(X \leq x) = \int_{-\infty}^{x} f(t) \, dt$
# - Greek letters: $\alpha, \beta, \gamma, \sigma, \mu$
#
# For a full reference, see the [LaTeX math guide](https://en.wikibooks.org/wiki/LaTeX/Mathematics).

# %% [markdown]
# # Python Code
#
# Code cells contain Python. When you run a code cell, Python executes the code and displays any output directly below.
#
# Let's start with some basics.

# %%
# Arithmetic
2 + 3

# %%
# Variables
x = 10
y = 4
print(x * y)

# %%
# A loop
for i in range(10):
    print(i)

# %% [markdown]
# ### Try it yourself
#
# In the cell below, write code that prints your name and a list of numbers counting up to your favorite number.

# %% [markdown]
# # Installing Packages
#
# Python's power comes from its packages — libraries that extend what Python can do. To install a package from within a notebook, use the `%pip` magic command:

# %%
# %pip install pandas matplotlib

# %% [markdown]
# This ensures the package is installed into the correct environment. You only need to install a package once, but the command is safe to re-run.
#
# For more details on managing environments (conda, venv, etc.), see **notes.md**.

# %% [markdown]
# # Working with Data
#
# The whole point of this course is to work with real data. Let's get a preview.
#
# We'll use `pandas`, the standard Python library for working with tabular data, to load a dataset of MLB player statistics.

# %%
import pandas as pd

df = pd.read_csv('../data/MLB.csv')
df.head()

# %%
# How big is the dataset?
df.shape

# %%
# Summary statistics
df.describe()

# %%
import matplotlib.pyplot as plt

plt.scatter(df['Age'], df['BA'], alpha=0.3)
plt.xlabel('Age')
plt.ylabel('Batting Average')
plt.title('MLB: Age vs. Batting Average')
plt.show()

# %% [markdown]
# We'll spend the rest of the course learning how to load, clean, explore, and analyze datasets like this one.

# %% [markdown]
# # Getting Help
#
# Three tools you'll use constantly:

# %% [markdown]
# **`help()`** — Python's built-in help function:
# ```python
# help(len)
# ```

# %% [markdown]
# **`?`** — Jupyter shortcut for help:
# ```python
# len?
# ```

# %% [markdown]
# **Tab completion** — Start typing and press `Tab` to see available options:
# ```python
# df.des  # press Tab here
# ```
