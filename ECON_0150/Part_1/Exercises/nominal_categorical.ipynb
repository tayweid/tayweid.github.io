# %% [markdown]
# ## Nominal Data Summary and Visualization
#
# This notebook summarizes and visualizes the nominal categorical dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load the nominal dataset

# %%
data_path = "nominal_categorical_dataset.csv"  # Update this path if necessary
df = pd.read_csv(data_path)

# %% [markdown]
# ### Summarize the dataset

# %%
summary = df['Sector'].value_counts()
print(summary)
# Out:
# Sector
# Services         37
# Unemployed       22
# Manufacturing    21
# Agriculture      20
# Name: count, dtype: int64

# %% [markdown]
# ### Visualize the dataset

# %%
plt.figure(figsize=(8, 6))
summary.plot(kind='barh', color=['blue', 'green', 'red', 'purple'])
plt.title("Employment Sector Distribution")
plt.ylabel("")
plt.xlabel("Count")
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()
