# %% [markdown]
# # Exercise 1.0 | Variable Types
#
# Determine which variable types are contained in each dataset.

# %%
# Imports
import pandas as pd

# File Path
file_path = 'https://tayweid.github.io/econ-0150/concepts/concept-1-0/data/'

# %% [markdown]
# ## Dataset 1: employment_status.csv

# %%
employment = pd.read_csv(file_path + 'employment_status.csv')
employment.head()
# Out:
#   Household ID Employment Status  Unnamed: 2  Unnamed: 3
# 0         D001        Unemployed         NaN  Unemployed
# 1         D002          Employed         NaN    Employed
# 2         D003          Employed         NaN         NaN
# 3         D004          Employed         NaN         NaN
# 4         D005          Employed         NaN         NaN

# %% [markdown]
# ## Dataset 2: employment_sector.csv

# %%
sector = pd.read_csv(file_path + 'employment_sector.csv')

# %% [markdown]
# ## Dataset 3: economic_optimism.csv

# %%
optimism = pd.read_csv(file_path + 'economic_optimism.csv')

# %% [markdown]
# ## Dataset 4: household_size.csv

# %%
size = pd.read_csv(file_path + 'household_size.csv')

# %% [markdown]
# ## Dataset 5: household_income.csv

# %%
income = pd.read_csv(file_path + 'household_income.csv')
