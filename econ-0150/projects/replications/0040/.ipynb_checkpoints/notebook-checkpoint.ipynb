# %% [markdown]
# # ECON 0150 | Replication Notebook
#
# **Title:** Urban-Rural Polarization
#
# **Original Authors:** Sobolewski, Teets
#
# **Original Date:** Fall 2025
#
# ---
#
# This notebook replicates the analysis from a student final project in ECON 0150: Economic Data Analysis.

# %% [markdown]
# ## About This Replication
#
# **Research Question:** How has Democratic vote share changed across counties from 2000 to 2016, and do these trends point to widening urban-rural polarization?
#
# **Data Source:** County presidential election results 2000-2024
#
# **Methods:** OLS regression with interaction term (log votes x year)
#
# **Main Finding:** The positive interaction term (0.019, p < 0.001) confirms widening polarization: urban counties shifted more Democratic while rural counties shifted more Republican between 2000 and 2016.
#
# **Course Concepts Used:**
# - OLS regression
# - Log transformations
# - Interaction terms
# - Difference-in-differences logic

# %% [markdown]
# ---
# ## Step 0 | Setup

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf

# %%
# Load data from course website
data_url = 'https://tayweid.github.io/econ-0150/projects/replications/0040/data/countypres_2000-2024.csv'
raw_data = pd.read_csv(data_url)
raw_data.head()
# Out:
#    year    state state_po county_name  county_fips        office  \
# 0  2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 1  2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 2  2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 3  2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 4  2000  ALABAMA       AL     BALDWIN       1003.0  US PRESIDENT
#
#         candidate       party  candidatevotes  totalvotes   version   mode
# 0         AL GORE    DEMOCRAT            4942       17208  20250821  TOTAL
# 1  GEORGE W. BUSH  REPUBLICAN           11993       17208  20250821  TOTAL
# 2           OTHER       OTHER             113       17208  20250821  TOTAL
# 3     RALPH NADER       GREEN             160       17208  20250821  TOTAL
# 4         AL GORE    DEMOCRAT           13997       56480  20250821  TOTAL

# %% [markdown]
# ---
# ## Step 1 | Data Preparation

# %%
# Filter to Democratic votes and calculate vote share
data = data[data['party'] == 'DEMOCRAT']
data['d_share'] = data['candidatevotes'] / data['totalvotes']

# Keep only 2000 and 2016
data = data[data['year'].isin([2000, 2016])]
data['now'] = (data['year'] == 2016).astype(int)
data['log_votes'] = np.log(data['totalvotes']+1)

data.head()
# Out:
#     year    state state_po county_name  county_fips        office candidate  \
# 0   2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT   AL GORE
# 4   2000  ALABAMA       AL     BALDWIN       1003.0  US PRESIDENT   AL GORE
# 8   2000  ALABAMA       AL     BARBOUR       1005.0  US PRESIDENT   AL GORE
# 12  2000  ALABAMA       AL        BIBB       1007.0  US PRESIDENT   AL GORE
# 16  2000  ALABAMA       AL      BLOUNT       1009.0  US PRESIDENT   AL GORE
#
#        party  candidatevotes  totalvotes   version   mode   d_share  now  \
# 0   DEMOCRAT            4942       17208  20250821  TOTAL  0.287192    0
# 4   DEMOCRAT           13997       56480  20250821  TOTAL  0.247822    0
# 8   DEMOCRAT            5188       10395  20250821  TOTAL  0.499086    0
# 12  DEMOCRAT            2710        7101  20250821  TOTAL  0.381636    0
# 16  DEMOCRAT            4977       17973  20250821  TOTAL  0.276915    0
#
#     log_votes
# 0    9.753188
# 4   10.941660
# 8    9.249176
# 12   8.868132
# 16   9.796682

# %% [markdown]
# ---
# ## Step 2 | Visualization

# %%
# Democratic vote share vs county size (total votes) by year
palette = {2000: 'blue', 2016: 'red'}
sns.lmplot(data, x='totalvotes', y='d_share', hue='year', logx=True, scatter=False, ci=None, palette=palette)
sns.scatterplot(data.sample(2000), x='totalvotes', y='d_share', hue='year', palette=palette, alpha=0.1, legend=False)
plt.xscale('log')

plt.xlabel("Total Votes (log scale)")
plt.ylabel("Democratic Vote Share")
plt.title("Urban-Rural Polarization: 2000 vs 2016")
# Out:
# Text(0.5, 1.0, 'Urban-Rural Polarization: 2000 vs 2016')

# %% [markdown]
# ---
# ## Step 3 | Statistical Analysis

# %%
# OLS with interaction term
model = smf.ols("d_share ~ log_votes + now + log_votes:now", data).fit()
print(model.summary().tables[1])
# Out:
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.0955      0.015      6.339      0.000       0.066       0.125
# log_votes         0.0324      0.002     20.236      0.000       0.029       0.036
# now              -0.2698      0.021    -12.984      0.000      -0.311      -0.229
# log_votes:now     0.0195      0.002      8.897      0.000       0.015       0.024
# =================================================================================

# %%
# Residual plot
data['residuals'] = model.resid

plt.figure(figsize=(10, 6))
sns.scatterplot(data.sample(1000), x="totalvotes", y="residuals", hue="now", alpha=0.3)
plt.xscale("log")
plt.axhline(0, color='r', linestyle='--')
plt.xlabel("Total Votes (log scale)")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()

# %% [markdown]
# ---
# ## Step 4 | Results Interpretation
#
# ### Key Findings
#
# - **log_votes coefficient (2000):** 0.032 - larger counties vote more Democratic
# - **now coefficient:** -0.27 - overall shift toward Republicans in 2016
# - **Interaction term:** +0.019 (p < 0.001) - but this shift was smaller in urban counties
#
# ### Conclusion
#
# The positive interaction confirms widening polarization: urban areas became relatively more Democratic while rural areas became more Republican between 2000 and 2016.

# %% [markdown]
# ---
# ## Replication Exercises
#
# ### Exercise 1: Different Years
# Compare 2000 vs 2024 instead of 2000 vs 2016. Has polarization continued?
#
# ### Exercise 2: State Analysis
# Filter to a single state and run the analysis. Does your state show the same pattern?
#
# ### Exercise 3: Swing States
# Compare polarization trends in swing states vs non-swing states.
#
# ### Challenge Exercise
# Calculate the predicted Democratic vote share for a county with 10,000 votes vs 1,000,000 votes in both 2000 and 2016. Quantify the divergence.

# %%
# Your code for exercises
