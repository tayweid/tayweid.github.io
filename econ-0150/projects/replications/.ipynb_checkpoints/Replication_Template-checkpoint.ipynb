# %% [markdown]
# # ECON 0150 | Replication Notebook
#
# **Title:** [Project Title]
#
# **Original Authors:** [Names]
#
# **Original Date:** Fall 2024
#
# ---
#
# This notebook replicates the analysis from a student final project in ECON 0150: Economic Data Analysis. You can run this notebook yourself to explore the data, reproduce the findings, and try the extension exercises at the end.

# %% [markdown]
# ## About This Replication
#
# **Research Question:** [What question does this project answer?]
#
# **Data Source:** [Where did the data come from?]
#
# **Methods:** [What statistical methods were used?]
#
# **Main Finding:** [One-sentence summary of the key result]
#
# **Course Concepts Used:**
# - [e.g., OLS regression]
# - [e.g., Categorical control variables]
# - [e.g., Residual analysis]

# %% [markdown]
# ---
# ## Step 0 | Setup
#
# First, we import the necessary libraries and load the data.

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf

# %%
# Load data from course website
data_url = 'https://tayweid.github.io/econ-0150/projects/replication/data/[DATASET_NAME].csv'
data = pd.read_csv(data_url)

# Preview the data
data.head()

# %%
# Check the shape and columns
print(f"Dataset has {len(data)} rows and {len(data.columns)} columns")
print(f"\nColumns: {list(data.columns)}")

# %% [markdown]
# ---
# ## Step 1 | Data Exploration
#
# Before analyzing the data, we explore its structure and key variables.

# %%
# Summary statistics
data.describe()

# %%
# [Additional exploration code - distributions, value counts, etc.]

# %% [markdown]
# ---
# ## Step 2 | Data Preparation
#
# We prepare the data for analysis by creating new variables, handling missing values, and transforming as needed.

# %%
# [Data cleaning and transformation code]

# %% [markdown]
# ---
# ## Step 3 | Visualization
#
# We visualize the key relationships in the data.

# %%
# [Key visualizations - scatterplots, boxplots, histograms, etc.]

# %% [markdown]
# ---
# ## Step 4 | Statistical Analysis
#
# We run the statistical model to answer the research question.

# %%
# [Statistical model - OLS regression, t-test, etc.]
# model = smf.ols('Y ~ X', data=data).fit()
# print(model.summary())

# %% [markdown]
# ---
# ## Step 5 | Results Interpretation
#
# [Explain what the results mean in plain English. Include key statistics like coefficients, p-values, and R-squared.]

# %%
# [Optional: residual analysis, diagnostic plots, etc.]

# %% [markdown]
# ---
# ## Replication Exercises
#
# Try extending this analysis with the following exercises:
#
# ### Exercise 1: [Title]
# [Description of the exercise - e.g., "Add education level as a control variable. Does this change the main finding?"]
#
# ### Exercise 2: [Title]
# [Description - e.g., "Create a residual plot. Do the OLS assumptions appear to be satisfied?"]
#
# ### Exercise 3: [Title]
# [Description - e.g., "Try an interaction term between X and Z. Is the relationship different for different groups?"]
#
# ### Challenge Exercise
# [A more difficult extension - e.g., "Find additional data to merge in. How might this strengthen or weaken the analysis?"]

# %%
# Your code for Exercise 1

# %%
# Your code for Exercise 2

# %%
# Your code for Exercise 3

# %%
# Your code for Challenge Exercise
