# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf

# %%
data = pd.read_csv('data/usa_00046.csv')

# %%
data = data.sample(1_000_000)

# %%
data.to_csv('data/usa_00046_sample.csv')
