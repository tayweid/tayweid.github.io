# %% [markdown]
# # Homework 1.4 | Panel Data (Long Format) — Solutions
#
# *Homework is designed to both test your knowledge and challenge you to apply familiar concepts in new applications. Answer clearly and completely. You are welcomed and encouraged to work in groups so long as your work is your own. Submit your figures and answers to [Gradescope](https://www.gradescope.com).*

# %%
# Imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# File Path
file_path = 'https://tayweid.github.io/econ-0150/parts/part-1-4/data/'

# %% [markdown]
# ## Q1. Numerical Variables in Panel
#
# The following data on hours worked is available from Our World in Data. This question is aimed at practicing the skill of making comparisons of continuous variables displayed visually.
# ![hw_01.png](data:image/png;base64,...)

# %% [markdown]
# a) In which country did people work the most on average?
#
# - ***South Korea***
# - United States
# - Norway

# %% [markdown]
# b) When did Norwegians work less than Americans?
#
# - Before 1963
# - During 1963
# - ***After 1963***
# - Never

# %% [markdown]
# c) When was the largest difference between the longest and the shortest annual working time?
#
# - 1960s
# - ***1980s***
# - 2000s
# - 2010s

# %% [markdown]
# d) In the 1980s, roughly how many times more did an average South Korean work than an average Norwegian?
#
# - ***2x***
# - 3x
# - 4x
# - 5x

# %% [markdown]
# e) Use `working_north_america.csv` to create a multiple line plot showing the average annual hours worked by country for the United States, Canada, and Mexico between 1955 and 2015.

# %%
# Load Data
working = pd.read_csv(file_path + 'working_north_america.csv')
working.head()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipython-input-1553646521.py in <cell line: 0>()
#       1 # Load Data
# ----> 2 working = pd.read_csv(file_path + 'working.csv')
#       3 working.head()
#
# ...

# %%
import os
file_path = 'https://tayweid.github.io/econ-0150'
os.listdir(file_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2748726297.py in <cell line: 0>()
#       1 import os
#       2 file_path = 'https://tayweid.github.io/econ-0150'
# ----> 3 os.listdir(file_path)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'https://tayweid.github.io/econ-0150'

# %%
# Multi-line plot
sns.lineplot(working, x='Year', y='Average annual working hours per worker', hue='Entity')
plt.title('Average Annual Working Hours by Country')
# Out:
# <Axes: xlabel='Year', ylabel='Average annual working hours per worker'>

# %% [markdown]
# ## Q2. Multi-Country Coffee Production
#
# Using the dataset `selected_coffee_prod_in_years.csv`, which provides information on coffee production in different countries between 1961 and 2023:

# %%
# Load Data
coffee = pd.read_csv(file_path + 'selected_coffee_prod_in_years.csv')
coffee.head()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipython-input-547602215.py in <cell line: 0>()
#       1 # Load Data
# ----> 2 coffee = pd.read_csv(file_path + 'selected_coffee_prod_in_years.csv')
#       3 coffee.head()
#
# ...

# %% [markdown]
# a) Plot a line graph of global coffee production over time (the total across all countries for each year). Describe the trend.

# %%
# Calculate global production by year
global_prod = coffee.groupby('Year')['coffe_prod'].sum().reset_index()

# Plot
plt.figure(figsize=(10, 5))
sns.lineplot(data=global_prod, x='Year', y='coffe_prod')
plt.title('Global Coffee Production Over Time')
plt.ylabel('Production')
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# **Answer:** Global coffee production shows a general upward trend from 1961 to 2023, with some year-to-year variability. Production has roughly tripled over this period.

# %% [markdown]
# b) Plot a line graph of coffee production for each country over time. Include all countries in a single figure.

# %%
# Multi-line plot by country
plt.figure(figsize=(12, 6))
sns.lineplot(data=coffee, x='Year', y='coffe_prod', hue='Entity')
plt.title('Coffee Production by Country')
plt.ylabel('Production')
plt.xlabel('Year')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# %% [markdown]
# c) Create a faceted line plot showing coffee production over time, with each country in its own panel. (*Hint: use `sns.relplot()` with `col='Entity'` and `col_wrap=4`.*)

# %%
# Faceted plot
g = sns.relplot(data=coffee, x='Year', y='coffe_prod', col='Entity', col_wrap=4, kind='line', height=3, aspect=1.2)
g.set_titles('{col_name}')
g.set_axis_labels('Year', 'Production')
plt.tight_layout()

# %% [markdown]
# d) Compare your multi-line plot from (b) with your faceted plot from (c). Which visualization makes it easier to see individual country trends? Which makes it easier to compare countries to each other?

# %% [markdown]
# **Answer:** The faceted plot (c) makes it easier to see individual country trends because each country has its own panel with an appropriate y-axis scale. The multi-line plot (b) makes it easier to compare countries directly since they share the same axes, but smaller producers like Honduras and Ethiopia are hard to see due to Brazil's dominant scale.

# %% [markdown]
# **Answer:** Vietnam shows one of the most dramatic growth stories in coffee production. Production was nearly zero until the mid-1980s, then grew exponentially to become the world's second-largest producer by the 2000s. This transformation was driven by economic reforms (Doi Moi) starting in 1986, government support for coffee cultivation, and the expansion of robusta coffee farming in the Central Highlands region.
