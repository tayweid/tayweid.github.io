# %% [markdown]
# ## Exercise 1.4 | Panel Data
#
# Lets plot large orders by coffee shop.

# %%
# Imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# File Path
file_path = 'https://tayweid.github.io/econ-0150/parts/part-1-4/data/'

# %%
data = pd.read_csv(file_path + 'Coffee_Sales_Reciepts_Large.csv', index_col=0)
