# %% [markdown]
# # Exercise 1.bonus | GMT Transformations
#
# This exercise demonstrates how to standardize coffee shop opening times by timezone.

# %%
# Imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# File Path
file_path = 'https://tayweid.github.io/econ-0150/parts/part-1-bonus/data/'

# %% [markdown]
# ## Standardize Times by Timezone

# %%
# Load Dataset
hours = pd.read_csv(file_path + 'Starbucks_Location_Hours.csv', index_col=0)
hours.head()

# %%
hours['openGMT'] = hours['open'] - hours['GMT']

# %%
sns.histplot(hours, x='openGMT', bins=range(-10,30,1))

# %%
hours['openGMT24'] = hours['openGMT'].mod(24)

# %%
sns.histplot(hours, x='openGMT24', bins=range(0,24,1))
