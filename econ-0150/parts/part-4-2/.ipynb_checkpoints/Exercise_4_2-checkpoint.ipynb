# %% [markdown]
# # Exercise 4.2 | Categorical Predictors
#
# Do individuals earning under $35,000 report more poor mental health days?
#
# Using the 2011 Behavioral Risk Factor Surveillance System (BRFSS) to compare mental health outcomes across income groups.

# %%
# Imports
import pandas as pd
import statsmodels.formula.api as smf
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# File Path
file_path = 'https://tayweid.github.io/econ-0150/parts/part-4-2/data/'

# %%
# Load BRFSS data
data = pd.read_csv(file_path + 'BRFSS_cleaned.csv')

# Create binary indicator: income below $35k (INCOME2 categories 1-5)
data['low_income'] = (data['INCOME2'] <= 5).astype(int)

# Keep relevant columns
data = data[['low_income', 'MENTHLTH']].dropna()
data
# Out:
#         low_income  MENTHLTH
# 0                0       0.0
# 1                0       0.0
# 2                0       0.0
# 3                1       5.0
# 4                1       0.0
# ...            ...       ...
# 243397           0       3.0
# 243398           0       0.0
# 243399           0       0.0
# 243400           0       0.0
# 243401           1      22.0
#
# [238881 rows x 2 columns]

# %% [markdown]
# #### Step 1. Summarize the data
#
# Visualize the distribution of mental health days by income group.

# %% [markdown]
# #### Step 2 & 3: Build and estimate the model
#
# $$MentalHealthDays = \beta_0 + \beta_1 \cdot LowIncome + \varepsilon$$

# %% [markdown]
# #### Step 4: Check the residuals
#
# Plot residuals vs. fitted values. What do you notice?

# %% [markdown]
# (*we'll explore this later*)

# %% [markdown]
# #### Step 5: Communicate the findings
#
# Interpret $\beta_0$ and $\beta_1$. What does our test tell us about the relationship between income and mental health?
