# %% [markdown]
# # Exercise 5 | Gender Wage Gap

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import seaborn as sns
import os

# File Path
colab_path = '/content/drive/MyDrive/Colab Notebooks/'
file_path = 'Part_5'

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
os.chdir(colab_path + file_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Gender Wage Gap

# %%
# Import Dataset From Part_5 Folder
data = pd.read_csv('USA Sample Data.csv')

# Create a variable: MALE
data['MALE'] = 1 - data['SEX']

# Print dataset for examination
data.head()
# Out:
#    YEAR  SAMPLE   SERIAL      CBSERIAL  HHWT       CLUSTER  STRATA  GQ  \
# 0  2019  201901   583089  2.019000e+12   128  2.019010e+12   80023   1
# 1  2019  201901   409203  2.019000e+12    71  2.019000e+12  280013   1
# 2  2019  201901   933278  2.019000e+12    55  2.019010e+12  330037   1
# 3  2019  201901  1284339  2.019000e+12   174  2.019010e+12  630248   1
# 4  2019  201901   801415  2.019000e+12   107  2.019010e+12   30534   1
#
#    PERNUM  PERWT  SEX  AGE  EDUC  EDUCD  DEGFIELD  DEGFIELDD  INCTOT  \
# 0       1    128    1   51     6     63         0          0   38500
# 1       2     75    0   24     6     63         0          0   15000
# 2       1     56    1   67     7     71         0          0    9600
# 3       2    244    0   42     6     61         0          0   45000
# 4       1    107    0   42    10    101        62       6203  100000
#
#    INCLOG10  EDU  MALE
# 0  4.585461   12     0
# 1  4.176091   12     1
# 2  3.982271   13     0
# 3  4.653213   12     1
# 4  5.000000   16     1

# %% [markdown]
# ## Model 1 | Fixed Effect, t-Test

# %% [markdown]
# ## Model 2 | Fixed Effect With Education Control

# %% [markdown]
# ## Model 3 | Differential Returns to Education

# %% [markdown]
# ## Model 4 | Full Model
