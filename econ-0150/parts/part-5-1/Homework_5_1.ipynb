# %% [markdown]
# # ECON 0150 | Fall 2025 | Homework 5.1
#
# ### Due: Friday November 21 at 5PM
#
# Homework is designed to both test your knowledge and challenge you to apply familiar concepts in new applications. Answer clearly and completely. You are welcomed and encouraged to work in groups so long as your work is your own. Use the provided datasets to answer the following questions. Then submit your figures and answers to Gradescope.

# %%
# Imports
import pandas as pd
import statsmodels.formula.api as smf
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# File Path
file_path = 'https://tayweid.github.io/econ-0150/parts/part-4-3/data/'

# %% [markdown]
# #### Q1. Mental Health and County Unemployment
#
# In Homework 4.3, you estimated the relationship between county-level unemployment and self-reported mental health using 2011 BRFSS data. You now have an extended version of the dataset that includes additional individual-level control variables.

# %%
data = pd.read_csv(file_path + 'BRFSS_cleaned.csv')
data.head()
# Out:
#    GEOID   AGE  INCOME2  MENTHLTH                county_name  \
# 0   1073  48.0      8.0       0.0  Jefferson County, Alabama
# 1   1073  34.0      7.0       0.0  Jefferson County, Alabama
# 2   1073  75.0      6.0       0.0  Jefferson County, Alabama
# 3   1073  60.0      4.0       5.0  Jefferson County, Alabama
# 4   1073  78.0      1.0       0.0  Jefferson County, Alabama
#
#    unemployment_rate  Year  College  Married  Female   BMI5
# 0                9.3  2011        1      1.0       1  23.40
# 1                9.3  2011        1      0.0       0  30.13
# 2                9.3  2011        0      1.0       1  29.18
# 3                9.3  2011        1      1.0       0  32.02
# 4                9.3  2011        0      0.0       1  24.02

# %% [markdown]
# a) Estimate the following multiple regression model:
#
# \begin{align}
# \texttt{menthlth}_i = \beta_0 + \beta_1 \cdot \texttt{county_unemp}_i + \beta_2 \cdot X_{i1} + \beta_3 \cdot X_{i2} + \beta_4 \cdot X_{i3} + \varepsilon_i
# \end{align}
#
# where the additional variables $X_{i1}, X_{i2}, X_{i3}$ are `College`, `Married`, and `Female` in the dataset. Report your regression output.

# %% [markdown]
# b) Interpret the coefficient on `county_unemp`. How does it compare to the simple regression you ran in Homework 4.2? Has the estimate changed in sign, magnitude, or significance?
