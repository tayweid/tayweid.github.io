# %% [markdown]
# # Exercise 2.5
#
# An example of a final project idea, inspired by one of your classmates.

# %%
# Imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# File Path
file_path = 'https://tayweid.github.io/econ-0150/parts/part-2-5/data/'

# %% [markdown]
# ## Presidential Elections

# %%
# Load Data
elections = pd.read_csv(file_path + 'Democratic_Share_Presidential_Wide.csv', index_col=0)
elections
# Out:
#       county_fips      2000      2004      2008      2012      2016      2020  \
# 0           10001  0.486228  0.430514  0.549570  0.525066  0.474126  0.520705
# 1           10003  0.618743  0.610978  0.705544  0.672871  0.655757  0.688198
# 2           10005  0.462080  0.390371  0.456708  0.434067  0.385829  0.443133
# 3            1001  0.291822  0.238448  0.259321  0.268006  0.246225  0.274423
# 4            1003  0.255099  0.227490  0.240351  0.218190  0.202078  0.227317
# ...           ...       ...       ...       ...       ...       ...       ...
# 3195         9007  0.596565  0.572931  0.616795  0.580441  0.538528  0.582979
# 3196         9009  0.616892  0.553791  0.617093  0.612802  0.563842  0.588161
# 3197         9011  0.594871  0.569534  0.606672  0.592815  0.535329  0.581823
# 3198         9013  0.575945  0.556122  0.605798  0.563854  0.529656  0.558951
# 3199         9015  0.589796  0.532980  0.616754  0.567676  0.458403  0.478199
#
#           2024
# 0     0.510175
# 1     0.665395
# 2     0.444505
# 3     0.266411
# 4     0.206524
# ...        ...
# 3195  0.565321
# 3196  0.560891
# 3197  0.564170
# 3198  0.540820
# 3199  0.447860
#
# [3200 rows x 8 columns]

# %%
sns.histplot(elections, x='2016')
# Out:
# <Axes: xlabel='2016', ylabel='Count'>

# %%
dem = elections[elections['2024'] > elections['2020']]
sns.scatterplot(dem, x='2020', y='2024', color='royalblue')
rep = elections[elections['2024'] < elections['2020']]
sns.scatterplot(rep, x='2020', y='2024', color='firebrick')
# Out:
# <Axes: xlabel='2020', ylabel='2024'>

# %% [markdown]
# ## Median Household Income

# %%
# Load Data
income = pd.read_csv(file_path + 'Income_By_County.csv', index_col=0)
income.head()
# Out:
#    State FIPS Code  County FIPS Code Postal Code            Name  \
# 0                0                 0          US   United States
# 1                1                 0          AL         Alabama
# 2                1                 1          AL  Autauga County
# 3                1                 3          AL  Baldwin County
# 4                1                 5          AL  Barbour County
#
#   Poverty Estimate, All Ages 90% CI Lower Bound 90% CI Upper Bound  \
# 0                 40,763,043         40,485,829         41,040,257
# 1                    780,043            762,230            797,856
# 2                      7,004              5,599              8,409
# 3                     24,942             20,972             28,912
# 4                      5,585              4,266              6,904
#
#   Poverty Percent, All Ages 90% CI Lower Bound.1 90% CI Upper Bound.1  ...  \
# 0                      12.5                 12.4                 12.6  ...
# 1                      15.7                 15.3                 16.1  ...
# 2                      11.7                  9.3                 14.1  ...
# 3                        10                  8.4                 11.6  ...
# 4                      25.5                 19.5                 31.5  ...
#
#   Median Household Income 90% CI Lower Bound.6 90% CI Upper Bound.6  \
# 0                 77719.0               77,533               77,905
# 1                 62248.0               61,546               62,950
# 2                 68857.0               62,667               75,047
# 3                 74248.0               69,046               79,450
# 4                 45298.0               40,531               50,065
#
#   Poverty Estimate, Age 0-4 90% CI Lower Bound.7 90% CI Upper Bound.7  \
# 0                 3,027,969            2,977,590            3,078,348
# 1                    66,457               61,943               70,971
# 2                         .                    .                    .
# 3                         .                    .                    .
# 4                         .                    .                    .
#
#   Poverty Percent, Age 0-4 90% CI Lower Bound.8 90% CI Upper Bound.8  \
# 0                     16.8                 16.5                 17.1
# 1                     23.2                 21.6                 24.8
# 2                        .                    .                    .
# 3                        .                    .                    .
# 4                        .                    .                    .
#
#   county_fips
# 0           0
# 1        1000
# 2        1001
# 3        1003
# 4        1005
#
# [5 rows x 32 columns]

# %%
income['Median Household Income'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ## Question 2: How is income related to election shift?

# %%
# Merge datasets on county FIPS
data = pd.merge(elections, income,
                  left_on='county_fips',
                  right_on='county_fips')

# %%
data.head()
# Out:
#    county_fips      2000      2004      2008      2012      2016      2020  \
# 0        10001  0.486228  0.430514  0.549570  0.525066  0.474126  0.520705
# 1        10003  0.618743  0.610978  0.705544  0.672871  0.655757  0.688198
# 2        10005  0.462080  0.390371  0.456708  0.434067  0.385829  0.443133
# 3         1001  0.291822  0.238448  0.259321  0.268006  0.246225  0.274423
# 4         1003  0.255099  0.227490  0.240351  0.218190  0.202078  0.227317
#
#        2024  State FIPS Code  County FIPS Code  ... 90% CI Upper Bound.5  \
# 0  0.510175               10                 1  ...                 19.8
# 1  0.665395               10                 3  ...                 16.1
# 2  0.444505               10                 5  ...                 20.1
# 3  0.266411                1                 1  ...                 21.2
# 4  0.206524                1                 3  ...                 16.1
#
#   Median Household Income 90% CI Lower Bound.6 90% CI Upper Bound.6  \
# 0                 72498.0               67,331               77,665
# 1                 86798.0               83,802               89,794
# 2                 78092.0               74,172               82,012
# 3                 68857.0               62,667               75,047
# 4                 74248.0               69,046               79,450
#
#   Poverty Estimate, Age 0-4 90% CI Lower Bound.7 90% CI Upper Bound.7  \
# 0                         .                    .                    .
# 1                         .                    .                    .
# 2                         .                    .                    .
# 3                         .                    .                    .
# 4                         .                    .                    .
#
#   Poverty Percent, Age 0-4 90% CI Lower Bound.8 90% CI Upper Bound.8
# 0                        .                    .                    .
# 1                        .                    .                    .
# 2                        .                    .                    .
# 3                        .                    .                    .
# 4                        .                    .                    .
#
# [5 rows x 39 columns]

# %%
data['dem_shift'] = data['2024'] - data['2012']

# %%
sns.scatterplot(data, x='Median Household Income', y='dem_shift')
# horizontal line at zero
plt.axhline(0, color='red')
sns.scatterplot(data, x='Median Household Income', y='dem_shift', hue='dem_shift')
# Out:
# <Axes: xlabel='Median Household Income', ylabel='dem_shift'>
