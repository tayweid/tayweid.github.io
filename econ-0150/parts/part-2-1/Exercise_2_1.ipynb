# %% [markdown]
# # Exercise 2.1 | Bivariate Relationships

# %%
# Imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Load Data
file_path = 'https://tayweid.github.io/econ-0150/parts/part-2-1/data/'

# %% [markdown]
# ## Anscombe's Quartet
#
# These four datasets have the same mean, standard deviation, and correlation.

# %%
# Load Anscombe's quartet (built into seaborn)
anscombe = sns.load_dataset('anscombe')
anscombe.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
# Summary statistics by dataset
anscombe.groupby('dataset').agg({'x': ['mean', 'std'], 'y': ['mean', 'std']})
# Out:
#            x                   y
#         mean       std      mean       std
# dataset
# I        9.0  3.316625  7.500909  2.031568
# II       9.0  3.316625  7.500909  2.031657
# III      9.0  3.316625  7.500000  2.030424
# IV       9.0  3.316625  7.500909  2.030579

# %% [markdown]
# ## Coffee Production and GDP
#
# Was the relationship between coffee production and GDP different in 1980?

# %%
gdp = pd.read_csv(file_path + 'Beans_GDP_1980.csv', index_col=0)
gdp.head()

# %% [markdown]
# ## Coffee and Oil Prices
#
# But are the two prices positively or negatively related to each other?

# %%
prices = pd.read_csv(file_path + 'Coffee_Oil.csv')
prices.head()
# Out:
#    Year  Coffee     Oil
# 0  2001    0.88  153.73
# 1  2002    0.84  157.37
# 2  2003    0.95  181.32
# 3  2004    1.13  240.65
# 4  2005    1.54  342.88
