# %% [markdown]
# # Homework 1.3
#
# *Homework is designed to both test your knowlege and challenge you to apply familiar concepts in new applications. Answer clearly and completely. You are welcomed and encouraged to work in groups so long as your work is your own. Submit your figures and answers to [Gradescope](https://www.gradescope.com).*

# %%
# Imports
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load Data
file_path = 'https://tayweid.github.io/econ-0150/parts/part-1-3/data/'

# %% [markdown]
# ## Question 1. Coffee Sales Receipts

# %% [markdown]
# a) What is the data structure of `Coffee_Sales_Reciepts.csv`?

# %%
receipts = pd.read_csv(file_path + 'Coffee_Sales_Receipts.csv')
receipts
# Out:
#          Shop  Price  Hour (out of 24)
# 0      Shop A   2.50                12
# 1      Shop A   3.50                15
# 2      Shop A   2.50                14
# 3      Shop A   2.50                16
# 4      Shop A   2.45                19
# ...       ...    ...               ...
# 46163  Shop C   3.00                15
# 46164  Shop C   3.75                15
# 46165  Shop C   2.20                11
# 46166  Shop C   2.50                15
# 46167  Shop C   3.50                15
#
# [46168 rows x 3 columns]

# %% [markdown]
# The dataset has `Shop`, a categorical variable representing multiple entities, and `Hour (out of 24)` a numerical variable representing the hour of the day. This has both cross-sectional variation between shops and timeseries variation through time, so it is panel data.

# %% [markdown]
# ## Question 2. Starbucks Location Hours

# %% [markdown]
# a) How was Starbucks_Location_Hours.csv collected? *(Hint: use the link provided on the course website.)*

# %% [markdown]
# Using the [source link](https://www.kaggle.com/datasets/kukuroo3/starbucks-locations-worldwide-2021-version), this data was scraped from the Starbucks website.

# %% [markdown]
# b) What is the data structure of `Starbucks_Location_Hours.csv`?

# %%
hours = pd.read_csv(file_path + 'Starbucks_Location_Hours.csv')
hours.head()
# Out:
#     storeNumber opening_times
# 0   34638-85784       8:30:00
# 1  32141-267986       7:30:00
# 2  15035-155445       8:00:00
# 3  49646-268445       8:00:00
# 4  31944-224544       8:00:00

# %% [markdown]
# This dataset has `storeNumber`, a categorical variable representing cross-sectional variation across entities, which only appear once. So this dataset is best understood as cross-sectional data. But since it also contains information about opennings in `opening_times`, one could also make the case that it contains timeseries information.

# %% [markdown]
# ## Question 3. Coffee Production Through Time
#
# Using the dataset `coffee_prod_kenya.csv`, which provides information on Kenyan coffee production between 1961 and 2023:

# %% [markdown]
# a) Who collected `coffee_prod_kenya.csv`? *(Hint: use the link provided on the course website.)*

# %% [markdown]
# Using the [source link](https://ourworldindata.org/grapher/coffee-bean-production?tab=table), this data was collected by Food and Agriculture Organization of the United Nations.

# %% [markdown]
# b) What is the data structure of `coffee_prod_kenya.csv`?

# %%
coffee = pd.read_csv(file_path + 'coffee_prod_kenya.csv')
coffee.head()
# Out:
#    Year  coffe_prod
# 0  1961       28100
# 1  1962       50000
# 2  1963       40500
# 3  1964       41400
# 4  1965       39300

# %% [markdown]
# This dataset has `coffee_pro` through time (in `Year`), so this is timeseries data.

# %% [markdown]
# c) Plot a line graph of Kenyan coffee production over time.

# %%
# Plot coffe_prod in coffee as a linegraph
sns.lineplot(coffee, x='Year', y='coffe_prod')

# Optional Styling
plt.title('Kenyan Coffee Production (kg)')
plt.xlabel('')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# d) Describe the trend.

# %% [markdown]
# Kenyan coffee production increased between 1960 and the late 1980s and decreased afterward.
