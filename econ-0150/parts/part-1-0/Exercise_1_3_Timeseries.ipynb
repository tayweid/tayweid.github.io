# %% [markdown]
# # Exercise 1.3 | Data Structures and Timeseries
#
# - Distinguish between data structures.
# - Visualize timeseries data

# %%
# Imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# File Path
file_path = 'https://tayweid.github.io/econ-0150/parts/part-1-3/data/'

# %% [markdown]
# ## Dataset 1: Households
#
# What's the data structure type?

# %%
# Load the dataset
income = pd.read_csv(file_path + 'household_incomes.csv')

# %%
income
# Out:
#     Household ID  Year  Income (USD)
# 0           H001  2010      34610.47
# 1           H001  2011      45559.97
# 2           H001  2012      83698.17
# 3           H001  2013     115593.13
# 4           H001  2014      47060.79
# ..           ...   ...           ...
# 195         H020  2015      75858.85
# 196         H020  2016     115767.18
# 197         H020  2017      65801.99
# 198         H020  2018      62486.59
# 199         H020  2019      65766.41
#
# [200 rows x 3 columns]

# %% [markdown]
# ## Dataset 2: Households
#
# What's the data structure type?

# %%
# Load the dataset
savings = pd.read_csv(file_path + 'household_savings.csv')
savings
# Out:
#    Household ID   Rate
# 0          H001   9.32
# 1          H002  16.23
# 2          H003  12.32
# 3          H004  18.01
# 4          H005   6.26
# ..          ...    ...
# 95         H096   7.33
# 96         H097  18.65
# 97         H098  18.12
# 98         H099  19.55
# 99         H100  12.16
#
# [100 rows x 2 columns]

# %% [markdown]
# ## Dataset 3: Coffee Prices
#
# What's the data structure type?

# %%
# Load the dataset
prices = pd.read_csv(file_path + 'Monthly_Coffee_Prices.csv', index_col=0)
prices['date'] = pd.to_datetime(prices['date'])
prices['month'] = prices['date'].dt.month_name()

# %%
prices.head()
# Out:
#         date     price      month
# 0 1973-08-01  0.654840     August
# 1 1973-09-01  0.652700  September
# 2 1973-10-01  0.659552    October
# 3 1973-11-01  0.646810   November
# 4 1973-12-01  0.670937   December

# %%
sns.lineplot(prices, x='date', y='price')
plt.title('Monthly Coffee Prices')
plt.xlabel('')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
sns.boxplot(prices, y='month', x='price', whis=(0,100))
plt.title('Monthly Coffee Prices')
plt.xlabel('')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')
