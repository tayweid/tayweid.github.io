# %% [markdown]
# # Exercise 1.0 | Variable Types
#
# Determine which variable types are contained in each dataset.

# %%
# Imports
import pandas as pd

# File Path
file_path = 'https://tayweid.github.io/econ-0150/parts/part-1-0/data/'

# %% [markdown]
# ## Python Demo

# %%
x = 2
y = 1
w = 3

# %%
x + y + w
# Out:
# 6

# %%
name = 'Taylor '
last_name = 'Kaybill '
my_last_name = 'Weidman'

# %%
name + last_name + my_last_name
# Out:
# 'Taylor Kaybill Weidman'

# %%
import numpy as np

# %%
theta = 43.78
np.cos(theta)
# Out:
# np.float64(0.9796076190831156)

# %% [markdown]
# ## Dataset 1: employment_status.csv

# %%
employment = pd.read_csv(file_path + 'employment_status.csv')

# %%
employment['Employment Status'].unique()
# Out:
# array(['Unemployed', 'Employed'], dtype=object)

# %%
employment['Employment Status'].value_counts()
# Out:
# Employment Status
# Employed      51
# Unemployed    49
# Name: count, dtype: int64

# %% [markdown]
# ## Dataset 2

# %%
sector = pd.read_csv(file_path + 'employment_sector.csv')

# %%
sector['Sector'].value_counts()
# Out:
# Sector
# Services         37
# Unemployed       22
# Manufacturing    21
# Agriculture      20
# Name: count, dtype: int64
