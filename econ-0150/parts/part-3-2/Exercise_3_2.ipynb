# %% [markdown]
# # Exercise 3.2 | Sampling and the Central Limit Theorem
#
# In this exercise we generate samples and simulate the central limit theorem.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def sample(n_rolls, n_samples=1):
    # Dice rolling (uniform distribution from 1-6)
    return np.random.randint(1, 7, size=n_rolls).tolist()

def samples(n_rolls, n_samples):
    # Dice rolling (uniform distribution from 1-6)
    return [np.mean(sample(n_rolls)).mean() for _ in range(n_samples)]

# %% [markdown]
# ## Sample Size: $n=1$

# %%
sample(1)
# Out:
# [5]

# %%
#class_data_1 = [3, 3, 2, 1, 3, 4, 3, 5, 3, 2, 1, 5, 6, 2, 6, 6, 1, 3, 2, 3, 2, 1, 6, 3, 6, 3, 2, 4, 4, 5, 3, 5, 4, 6, 6, 4,]
class_data_1 = [6,4, 1, 1, 5, 3, 5, 4, 2, 1, 5, 2, 3, 2, 1, 2, 5, 2, 6, 4, 3, 4, 4, 5, 6]
sns.histplot(class_data_1, bins=[1,2,3,4,5,6,7])
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# ## Sample Size: $n=2$

# %%
s = sample(2)
s
# Out:
# [1, 5]

# %%
np.mean(s).item()
# Out:
# 3.0

# %%
class_data_2 = [2.5, 4.5, 2.5, 6, 2, 4.5, 3, 3.5, 3, 2.5, 4, 3, 1, 3, 4, 3.5, 3.5, 5.5, 2.5, 3, 5.5, 2.5, 5, 2, 4, 2, 4.5, 3, 3.5, 4, 5, 1, 3.5, 5.5, 4, 4]
class_data_2 = [1, 4.5, 4.5, 3, 3, 2, 4, 3.5, 2, 1.5, 4, 4, 3, 1, 3.5, 3.5, 4, 3.5, 2, 3, 2.5, 4, 3, 3.5, 6] + class_data_2
sns.histplot(class_data_2, bins=[1,1.5, 2,2.5,3,3.5,4,4.5, 5,5.5, 6,6.5])
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# ## Sample Size: $n=3$

# %%
sample_size = 3
number_of_samples = 100000
sample_means_3 = samples(sample_size, number_of_samples)

# %%
sns.histplot(sample_means_3, bins=15)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# ## Sample Size: $n=30$

# %%
sample_size = 30
number_of_samples = 1000
sample_means_30 = samples(sample_size, number_of_samples)

# %%
sns.histplot(sample_means_30, bins=np.linspace(1, 6.1, 31))
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# ## Sample Size: $n=1000$

# %%
sample_size = 1000
number_of_samples = 1000
sample_means_1000 = samples(sample_size, number_of_samples)

# %%
sns.histplot(sample_means_1000, bins=np.linspace(3, 4, 41))
# Out:
# <Axes: ylabel='Count'>
