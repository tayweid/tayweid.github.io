# %% [markdown]
# # Homework 1.4 | Panel Data (Long Format)
#
# *Homework is designed to both test your knowledge and challenge you to apply familiar concepts in new applications. Answer clearly and completely. You are welcomed and encouraged to work in groups so long as your work is your own. Submit your figures and answers to [Gradescope](https://www.gradescope.com).*

# %%
# Imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# File Path
file_path = 'https://tayweid.github.io/econ-0150/parts/part-1-4/data/'

# %% [markdown]
# ## Q1. Numerical Variables in Panel
#
# The following data on hours worked is available from Our World in Data. This question is aimed at practicing the skill of making comparisons of continuous variables displayed visually.
#
# ![](i/hw_01.png)

# %% [markdown]
# a) In which country did people work the most on average?
#
# - South Korea
# - United States
# - Norway

# %% [markdown]
# b) When did Norwegians work less than Americans?
#
# - Before 1963
# - During 1963
# - After 1963
# - Never

# %% [markdown]
# c) When was the largest difference between the longest and the shortest annual working time?
#
# - 1960s
# - 1980s
# - 2000s
# - 2010s

# %% [markdown]
# d) In the 1980s, roughly how many times more did an average South Korean work than an average Norwegian?
#
# - 2x
# - 3x
# - 4x
# - 5x

# %% [markdown]
# e) Use `working_north_america.csv` to create a multiple line plot showing the average annual hours worked by country for the United States, Canada, and Mexico between 1955 and 2015.

# %%
# Load Data
working = pd.read_csv(file_path + 'working_north_america.csv')
working.head()

# %% [markdown]
# ## Q2. Multi-Country Coffee Production
#
# Using the dataset `coffee_prod_in_years.csv`, which provides information on coffee production in different countries between 1961 and 2023:

# %%
# Load Data
coffee = pd.read_csv(file_path + 'coffee_prod_in_years.csv')
coffee.head()

# %% [markdown]
# a) Plot a line graph of global coffee production over time (the total across all countries for each year). Describe the trend and discuss potential reasons behind it.

# %% [markdown]
# b) Plot a line graph of coffee production for each country over time. Include all countries in a single figure using different colors for each country.

# %% [markdown]
# c) Choose one country that stands out in your multi-line plot and create a separate line graph showing just that country's coffee production over time. Describe the pattern and propose possible explanations (e.g., conflict, policy changes, new entrants to the market).

# %% [markdown]
# d) Create a faceted plot showing coffee production over time, with each country in its own panel. Compare this view to the multi-line plot from part (b). Which visualization do you find more useful for understanding the data? Why?
