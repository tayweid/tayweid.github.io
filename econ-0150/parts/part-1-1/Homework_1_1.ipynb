# %% [markdown]
# # Homework 1.1 | Categorical Variables
#
# *Homework is designed to both test your knowlege and challenge you to apply familiar concepts in new applications.
# Answer clearly and completely. You are welcomed and encouraged to work in groups so long as your work is your
# own. Submit your figures and answers to [Gradescope](https://www.gradescope.com).*
#
# Lets use the class survey dataset to understand who is in our class!

# %%
# Imports
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# File Path
file_path = 'https://tayweid.github.io/econ-0150/parts/part-0/data/'

# %%
# Load Data
data = pd.read_csv(file_path + 'S26.csv')
data.head()
# Out:
#    Entry When is your birthday? What is your favorite color?  \
# 0      0                4/18/06                         Pink
# 1      1                12/2/05                         Pink
# 2      2                5/19/06                        Black
# 3      3                5/27/08                       Purple
# 4      4                3/13/06                         Blue
#
#    Approximately how many miles away from Pittsburgh is your hometown?  \
# 0                                                175
# 1                                                300
# 2                                                  0
# 3                                                250
# 4                                                117
#
#   What country (or state if you're in the US) do you call home?  \
# 0                                       Pennsylvania
# 1                                       Pennsylvania
# 2                                                 PA
# 3                                                 PA
# 4                                      Pennsylvania
#
#   What is your year in college? What is your (primary) major?  \
# 0                     Sophomore                 Public Health
# 1                     Sophomore                     Economics
# 2                     Sophomore        Industrial Engineering
# 3                      Freshman             Political Science
# 4                     Sophomore                     Economics
#
#    How much did you like your statistics class?  \
# 0                                             9
# 1                                             7
# 2                                             5
# 3                                             5
# 4                                             9
#
#    How excited are you for this class? Do you feel confident in Excel?  \
# 0                                    7                              No
# 1                                    8                             Yes
# 2                                    7                             Yes
# 3                                    6                              No
# 4                                    6                             Yes
#
#    How confident do you feel in python?  When is your birthyear?  \
# 0                                     1                     2006
# 1                                     1                     2005
# 2                                     4                     2006
# 3                                     1                     2008
# 4                                     1                     2006
#
#    When is your birthmonth?
# 0                         4
# 1                        12
# 2                         5
# 3                         5
# 4                         3

# %% [markdown]
# ## Q1. Data Selection
#
# a) Who collected this data?

# %% [markdown]
# b) How was this data collected?

# %% [markdown]
# ## Q2. What is the index variable?

# %% [markdown]
# ## Q3. What is the data structure?

# %% [markdown]
# ## Q4. How many variables does the dataset contain?

# %% [markdown]
# ## Q5. For each of the following variables, what is the variable type?
#
# Choose from: Binary Categorical, Nominal Categorical, Ordinal Categorical, Discrete Numerical, Continuous Numerical

# %% [markdown]
# "What is your favorite color?"

# %% [markdown]
# "Approximately how many miles away from Pittsburgh is your hometown?"

# %% [markdown]
# "What is your (primary) major?"

# %% [markdown]
# "How much did you like your statistics class?"

# %% [markdown]
# "How excited are you for this class?"

# %% [markdown]
# "Do you feel confident in Excel?"

# %% [markdown]
# ## Q6. Summarizing 'Do you feel confident in Excel?'
#
# a) Appropriately visualize the variable 'Do you feel confident in Excel?'.

# %% [markdown]
# b) How many students in the class feel confident in Excel?

# %% [markdown]
# ## Q7. Summarizing 'What is your major?'
#
# a) Appropriately visualize the variable 'What is your major?'.

# %% [markdown]
# b) How many students in the dataset are economics majors?
