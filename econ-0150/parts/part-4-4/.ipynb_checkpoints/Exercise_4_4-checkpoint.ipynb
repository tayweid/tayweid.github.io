# %% [markdown]
# # Exercise 4.3 | Categorical Predictors
#
# Using a binary categorical variable to predict neighborhood pollution using median income.

# %%
# Imports
import pandas as pd
import statsmodels.formula.api as smf
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# File Path
file_path = 'https://tayweid.github.io/econ-0150/parts/part-4-3/data/'

# %%
data = pd.read_csv(file_path + 'neighborhood_greenspace.csv', index_col=0)
data
# Out:
#     temperature  high_green
# 0     22.745071         0.0
# 1     21.792604         0.0
# 2     22.971533         0.0
# 3     24.284545         0.0
# 4     21.648770         0.0
# ..          ...         ...
# 95    16.804728         1.0
# 96    19.444180         1.0
# 97    19.391583         1.0
# 98    19.007670         1.0
# 99    18.648119         1.0
#
# [100 rows x 2 columns]

# %% [markdown]
# #### Step 1. Summarize the data

# %% [markdown]
# #### Step 2 & 3: Built and estimate the model

# %% [markdown]
# #### Step 4: Check the residuals

# %% [markdown]
# #### Step 5: Communicate the findings
