# %% [markdown]
# # Exercise 1.2 | Numerical Variables

# %%
# Imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# File Path
file_path = 'https://tayweid.github.io/econ-0150/parts/part-1-2/data/'

# %% [markdown]
# ## Histograms: $40k Income Customers

# %%
customers = pd.read_csv(file_path + 'Starbucks_Customer_Profiles_40k.csv', index_col=0)

# %%
customers.head()
# Out:
#    gender  age                                id  became_member_on   income
# 34      M   40  f082d80f0aac47a99173ba8ef8fc1909          20160709  33000.0
# 41      F   20  02c083884c7d45b39cc68e1314fec56c          20160711  30000.0
# 42      M   45  c0d210398dee4a0895b24444a5fcd1d2          20180707  33000.0
# 46      F   69  8e7c7465e98c43d8a01f51e2b5c29542          20130918  37000.0
# 51      F   66  7584948ea6d04f94b8798624706261c2          20180408  38000.0

# %%
# Make a histogram using seaborn
sns.histplot(customers, x='age', bins=range(20,100,5))
# Add a title
plt.title('Starbucks Customers by Age')
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# ## Boxplot + Stripplot: Coffee Per Capita

# %%
coffee = pd.read_csv(file_path + 'Coffee_Per_Cap_2019.csv', index_col=0)

# %%
coffee.head()
# Out:
#   Code  Coffee_2019
# 0  AUT     7.925747
# 2  BGR     3.638313
# 3  HRV     5.623266
# 4  CYP     5.615070
# 5  CZE     4.739563

# %%
sns.boxplot(coffee, x='Coffee_2019', whis=(0,100))
sns.stripplot(coffee, x='Coffee_2019')
# Out:
# <Axes: xlabel='Coffee_2019'>
