# %% [markdown]
# # Exercise 1.2 | Cross-Sectional (Numerical) Data

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# File Path
file_path = 'https://tayweid.github.io/econ-0150/parts/part-1-2/data/'

# %% [markdown]
# ## Histograms: Starbucks Customer Ages
#
# **Question:** Which bin width works best?

# %%
# Load Data
customers = pd.read_csv(file_path + 'Starbucks_Customer_Profiles_40k.csv', index_col=0)

# %% [markdown]
# ## Describing Center and Spread
#
# Two numbers summarize a histogram: **mean** (center) and **standard deviation** (spread).

# %% [markdown]
# ## Boxplots and Quartiles: Coffee Per Capita
#
# When we have fewer observations, boxplots + stripplots work better than histograms. They show us the quartiles directly.

# %%
# Load Data
coffee = pd.read_csv(file_path + 'Coffee_Per_Cap_2019.csv', index_col=0)

# %% [markdown]
# ### Identifying Quartiles
#
# The boxplot shows five key values: minimum, Q1, median, Q3, and maximum.
