# %% [markdown]
# # Exercise 2.3 | Bivariate Relationships by Category
#
# Has the relationship between income and voting changed over time?

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Data path
file_path = 'https://tayweid.github.io/econ-0150/parts/part-2-3/data/'

# %% [markdown]
# ## Load the Data

# %%
# Elections data
elections_wide = pd.read_csv(file_path + 'Democratic_Share_Presidential_Wide.csv', index_col=0)
elections_wide.head()
# Out:
#    county_fips      2000      2004      2008      2012      2016      2020  \
# 0        10001  0.486228  0.430514  0.549570  0.525066  0.474126  0.520705
# 1        10003  0.618743  0.610978  0.705544  0.672871  0.655757  0.688198
# 2        10005  0.462080  0.390371  0.456708  0.434067  0.385829  0.443133
# 3         1001  0.291822  0.238448  0.259321  0.268006  0.246225  0.274423
# 4         1003  0.255099  0.227490  0.240351  0.218190  0.202078  0.227317
#
#        2024
# 0  0.510175
# 1  0.665395
# 2  0.444505
# 3  0.266411
# 4  0.206524

# %%
# Convert from long format to wide format
data_long = data.melt(
    id_vars=['county_fips', 'income'],
    value_vars=['2000', '2024'],
    var_name='Year',                                        
    value_name='dem_share'
)

# %%
# Use a boxplot
sns.boxplot(data_long, x='Year', y='dem_share', whis=(0,100))
sns.stripplot(data_long.sample(400), x='Year', y='dem_share')
# Out:
# <Axes: xlabel='Year', ylabel='dem_share'>

# %%
# Income data
income = pd.read_csv(file_path + 'Income_By_County.csv', index_col=0)
income = income[['county_fips', 'Median Household Income']].dropna()
income.columns = ['county_fips', 'income']
income.head()
# Out:
#    county_fips   income
# 0            0  77719.0
# 1         1000  62248.0
# 2         1001  68857.0
# 3         1003  74248.0
# 4         1005  45298.0

# %% [markdown]
# ## Merging Datasets
#
# To ask questions that require both income and elections data, we need to combine them using `pd.merge()`.

# %%
# Merge on county_fips
data = pd.merge(income, elections, on='county_fips')
data.head()
# Out:
#    county_fips   income      2000      2004      2008      2012      2016  \
# 0         1001  68857.0  0.291822  0.238448  0.259321  0.268006  0.246225
# 1         1003  74248.0  0.255099  0.227490  0.240351  0.218190  0.202078
# 2         1005  45298.0  0.504473  0.450284  0.492692  0.515791  0.471768
# 3         1007  56025.0  0.388085  0.276286  0.268543  0.264219  0.217603
# 4         1009  64962.0  0.282079  0.184675  0.147296  0.125174  0.086188
#
#        2020      2024
# 0  0.274423  0.266411
# 1  0.227317  0.206524
# 2  0.461391  0.425850
# 3  0.208811  0.176151
# 4  0.096523  0.092231

# %% [markdown]
# ## Question 1: Has county-level voting changed?
#
# Create a boxplot comparing Democratic vote share in 2000 vs 2024.

# %%
# Your code here

# %% [markdown]
# ## Question 2: Do large counties vote differently?
#
# Create a scatter plot of county size (total votes) vs Democratic share.

# %%
# Your code here

# %% [markdown]
# ## Question 3: Is this related to income?
#
# Create a scatter plot of income vs Democratic share (2024).

# %%
# Your code here

# %% [markdown]
# ## Question 4: Has the relationship changed?
#
# Create a scatter plot of income vs Democratic share, colored by year (2000 vs 2024).
#
# Hint: Use `hue='Year'` in `sns.lmplot()`

# %%
# Your code here
