# %% [markdown]
# # ECON 0150 | Spring 2025 | Homework 4.3

# %% [markdown]
# ### Due: Friday November 14 at 5PM
#
# Homework is designed to both test your knowledge and challenge you to apply familiar concepts in new applications. Answer clearly and completely. You are welcomed and encouraged to work in groups so long as your work is your own. Use the provided datasets to answer the following questions. Then submit your figures and answers to Gradescope.

# %%
# Imports
import pandas as pd
import statsmodels.formula.api as smf
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# File Path
file_path = 'https://tayweid.github.io/econ-0150/parts/part-4-3/data/'

# %% [markdown]
# ## Q1. Mental Health and Income Group

# %%
data = pd.read_csv(file_path + 'BRFSS_cleaned.csv')
data
# Out:
#         GEOID   AGE  INCOME2  MENTHLTH                county_name  \
# 0        1073  48.0      8.0       0.0  Jefferson County, Alabama
# 1        1073  34.0      7.0       0.0  Jefferson County, Alabama
# 2        1073  75.0      6.0       0.0  Jefferson County, Alabama
# 3        1073  60.0      4.0       5.0  Jefferson County, Alabama
# 4        1073  78.0      1.0       0.0  Jefferson County, Alabama
# ...       ...   ...      ...       ...                        ...
# 243397  56025  22.0      6.0       3.0    Natrona County, Wyoming
# 243398  56025  39.0      7.0       0.0    Natrona County, Wyoming
# 243399  56025  28.0      7.0       0.0    Natrona County, Wyoming
# 243400  56025  47.0      NaN       0.0    Natrona County, Wyoming
# 243401  56025  25.0      1.0      22.0    Natrona County, Wyoming
#
#         unemployment_rate  Year  College  Married  Female   BMI5
# 0                     9.3  2011        1      1.0       1  23.40
# 1                     9.3  2011        1      0.0       0  30.13
# 2                     9.3  2011        0      1.0       1  29.18
# 3                     9.3  2011        1      1.0       0  32.02
# 4                     9.3  2011        0      0.0       1  24.02
# ...                   ...   ...      ...      ...     ...    ...
# 243397                5.1  2011        1      0.0       1  24.28
# 243398                5.1  2011        0      1.0       1  22.05
# 243399                5.1  2011        1      1.0       1  27.46
# 243400                5.1  2011        0      0.0       1  25.84
# 243401                5.1  2011        1      0.0       0    NaN
#
# [243402 rows x 11 columns]

# %% [markdown]
# #### a) Run a linear regression such that the mental health variable is the outcome variable and the indicator for income less than \$10000 is the independent variable. Interpret your results.

# %%
# Create a binary categorical variable for those making less than 10k
data['under_10k'] = (data['INCOME2'] == 1).astype(int)

# %%
sns.scatterplot(data, x = 'under_10k', y = 'MENTHLTH')
# Out:
# <Axes: xlabel='under_10k', ylabel='MENTHLTH'>

# %%
# Step 1. write out a model
# MENTHLTH ~ b_0 + b_1 * under_10k

# Step 2. run a model
model = smf.ols(formula = 'MENTHLTH ~ under_10k', data = data).fit()
print(model.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.1877      0.016    200.921      0.000       3.157       3.219
# under_10k      4.8410      0.075     64.937      0.000       4.695       4.987
# ==============================================================================

# %%
# Step 3. interpret the model results

# the average number of mental health days is roughly 5 higher in the low income group
# we would see something this extreme vary rarely (under the null) if there was no difference

# %% [markdown]
# #### c) Run a linear regression such that the mental health variable is the outcome variable and the income indicator \$75,000 or more is the independent variable. Interpret your results.

# %%
# Create a binary categorical variable for those making more than 75k
# data['over_75k'] = (data['INCOME2'] == 8).astype(int)
