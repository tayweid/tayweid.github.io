# %% [markdown]
# # Exercise 0 | Diagramming Data
#
# Load each dataset and identify its structure, variable type, indices, and number of variables.

# %%
# Imports
import pandas as pd

# File Path
file_path = 'https://tayweid.github.io/econ-0150/parts/part-0/data/'

# %% [markdown]
# ## Python Basics

# %%
# Variables store values
x = 5
y = 3
x + y
# Out:
# 8

# %%
# Strings are text
greeting = 'Hello'
name = 'World'
greeting + ' ' + name
# Out:
# 'Hello World'

# %%
# pd.read_csv() loads data
df = pd.read_csv(file_path + 'dataset1.csv')
df
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipython-input-2641899514.py in <cell line: 0>()
#       1 # pd.read_csv() loads data
# ----> 2 df = pd.read_csv(file_path + 'dataset1.csv')
#       3 df
#
# ...

# %%
# .head() shows the first few rows
df.head()

# %%
# .shape shows (rows, columns)
df.shape

# %%
# .columns shows column names
df.columns

# %% [markdown]
# ## Dataset 1: dataset1.csv
#
# - **Index:** ?
# - **Structure:** ?
# - **Variable:** ?
# - **N Variables:** ?

# %%
d1 = pd.read_csv(file_path + 'dataset1.csv')
d1.head()

# %%
d1.shape

# %% [markdown]
# ## Dataset 2: dataset2.csv
#
# - **Index:** ?
# - **Structure:** ?
# - **Variable:** ?
# - **N Variables:** ?

# %%
d2 = pd.read_csv(file_path + 'dataset2.csv')
d2.head()

# %%
d2['Employment Status'].unique()

# %%
d2['Employment Status'].value_counts()

# %% [markdown]
# ## Dataset 3: dataset3.csv
#
# - **Index:** ?
# - **Structure:** ?
# - **Variable:** ?
# - **N Variables:** ?

# %%
d3 = pd.read_csv(file_path + 'dataset3.csv')
d3.head(10)

# %%
d3['Household ID'].unique()

# %%
d3['Year'].unique()

# %% [markdown]
# ## Dataset 4: dataset4.csv
#
# - **Index:** ?
# - **Structure:** ?
# - **Variable:** ?
# - **N Variables:** ?

# %%
d4 = pd.read_csv(file_path + 'dataset4.csv')
d4.head()

# %%
d4['Economic Optimism'].unique()

# %%
d4['Economic Optimism'].value_counts()

# %% [markdown]
# ## Dataset 5: dataset5.csv
#
# - **Index:** ?
# - **Structure:** ?
# - **Variable:** ?
# - **N Variables:** ?

# %%
d5 = pd.read_csv(file_path + 'dataset5.csv')
d5.head()

# %%
d5['Sector'].unique()

# %%
d5['Sector'].value_counts()
