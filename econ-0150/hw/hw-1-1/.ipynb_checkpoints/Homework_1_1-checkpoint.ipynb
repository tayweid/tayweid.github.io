# %% [markdown]
# # Homework 1.1

# %%
# Imports
import pandas as pd

# %%
# Load Data
url = 'https://tayweid.github.io/econ-0150/hw/hw-1-0/ECON_0150_Survey.csv'
data = pd.read_csv(url)
data.head()
# Out:
#    Unnamed: 0                  Timestamp  \
# 0           0  2025/01/08 3:44:16 PM EST
# 1           1  2025/01/08 3:57:15 PM EST
# 2           2  2025/01/08 3:57:15 PM EST
# 3           3  2025/01/08 3:57:17 PM EST
# 4           4  2025/01/08 3:57:18 PM EST
#
#   First and Last Initials (eg. Taylor Weidman -> TW)  \
# 0                                                 KL
# 1                                                 MD
# 2                                                 PO
# 3                                                 BP
# 4                                                 JM
#
#   What is your favorite color? What is your age?  \
# 0                          Red                20
# 1                         Blue                20
# 2                         Blue                20
# 3                          Red                19
# 4                         Blue                21
#
#   How many siblings to you have?  \
# 0                              2
# ...

# %% [markdown]
# #### Question 1.

# %%
#
