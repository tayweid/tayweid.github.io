# %% [markdown]
# # Homework 1.4

# %%
# Imports
import pandas as pd

# %%
# Load Data
#url = 'https://tayweid.github.io/econ-0150/hw/hw-1-4/'
#data = pd.read_csv(url)
data.head()

# %% [markdown]
# #### Question 1
