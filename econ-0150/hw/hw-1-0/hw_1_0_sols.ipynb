# %% [markdown]
# # Homework 1.0

# %%
# Imports
import pandas as pd

# %%
# Load Data
url = 'https://tayweid.github.io/econ-0150/hw/hw-1-0/ECON_0150_Survey.csv'
data = pd.read_csv(url)
data.head()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipython-input-3826321625.py in <cell line: 0>()
#       1 url = 'https://tayweid.github.io/econ-0150/hw/hw-1-0/ECON_0150_Survey.csv'
# ----> 2 data = pd.read_csv(url)
#       3 data.head()
#
# ...

# %% [markdown]
# #### Question 1.

# %%
#
