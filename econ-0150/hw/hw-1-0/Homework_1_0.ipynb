# %% [markdown]
# # Homework 1.0

# %%
# Imports
import pandas as pd

# File Path
file_path = 'https://tayweid.github.io/econ-0150/hw/hw-1-0/'

# %%
# Load Data
data = pd.read_csv(file_path + 'Economic Data Analysis | Day 1 Survey.csv')
data.head()
# Out:
# ---------------------------------------------------------------------------
# InvalidURL                                Traceback (most recent call last)
# /tmp/ipython-input-1152405449.py in <cell line: 0>()
#       1 # Load Data
# ----> 2 data = pd.read_csv(file_path + 'Economic Data Analysis | Day 1 Survey.csv')
#       3 data.head()
#
# ...
