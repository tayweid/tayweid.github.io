# %% [markdown]
# # Exercise 1.0 | Variable Types
#
# Identify the and visualizes the binary categorical dataset.

# %%
# Imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

file_path = 'https://tayweid.github.io/econ-0150/concepts/concept-1-0/data/'

# %% [markdown]
# ## Dataset 1

# %%
dataset1 = pd.read_csv(file_path + 'economic_optimism.csv')
dataset1.head()
# Out:
#      ID     Economic Optimism
# 0  B001  Somewhat Pessimistic
# 1  B002      Very Pessimistic
# 2  B003   Somewhat Optimistic
# 3  B004       Very Optimistic
# 4  B005  Somewhat Pessimistic

# %% [markdown]
# ## Dataset 2

# %%
dataset2 = pd.read_csv(file_path + 'employment_sector.csv')
dataset2.head()
# Out:
#      ID         Sector
# 0  A001       Services
# 1  A002    Agriculture
# 2  A003     Unemployed
# 3  A004  Manufacturing
# 4  A005  Manufacturing

# %% [markdown]
# ## Dataset 3

# %%
dataset3 = pd.read_csv(file_path + 'economic_optimism.csv')
dataset3.head()
# Out:
#      ID     Economic Optimism
# 0  B001  Somewhat Pessimistic
# 1  B002      Very Pessimistic
# 2  B003   Somewhat Optimistic
# 3  B004       Very Optimistic
# 4  B005  Somewhat Pessimistic

# %% [markdown]
# ## Dataset 4

# %%
dataset4 = pd.read_csv(file_path + 'household_size.csv')
dataset4.head()
# Out:
#   Household ID  Number of Children
# 0         H001                   5
# 1         H002                   4
# 2         H003                   4
# 3         H004                   5
# 4         H005                   5

# %% [markdown]
# ## Dataset 5

# %%
dataset5 = pd.read_csv(file_path + 'household_income.csv')
dataset5.head()
# Out:
#   Household ID  Household Income (USD)
# 0         C001               109879.71
# 1         C002                82496.44
# 2         C003                89562.91
# 3         C004                41550.11
# 4         C005                51284.65
